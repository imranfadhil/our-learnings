# %% [markdown]
# # Advanced Unsupervised ML

# %% [markdown]
# ### Descriptor: Knowledge Level
# 1. Able to explain characteristics of high-dimensional clustering techniques and their challenges.
# 2. Able to describe and compare cutting edge tools and techniques in unsupervised machine learning.
# 3. Able to use advanced unsupervised machine learning algorithms.

# %% [markdown]
# ### 1. High Dimensional Clustering
#
# Curse of Dimensionality
# - Increase computational requirement
# - Not visual friendly
#
#
# #### High Dimensional Clustering Techniques
# - Dimensionality Reduction
#     - Feature selection
#     - Feature reduction: PCA (Principal Component Analysis)
# - Association Rule Analysis
#
#
# ##### PCA
# - Reduce dimensionality by using principal components.
# - To find the first linear combination of input variables which maximizes the variance of the data. Followed by the next component which resulted in highest resiudal variance. And so on.
# - Challenges:
#     - Loose the explainability
#     - Different clusters might be relevant to certain subfeatures (global vs local subspaces).
#
# ##### Association Rule Analysis
# - Find frequently occuring patterns/ correlation/ associations between sets of elements in the data.
# - Result will be in "if-then" statements
# - Apriori algorithm vs Frequent Pattern (FP)-growth algorithm

# %% [markdown]
# ### 2. Different Unsupervised ML Tools and Techniques
#
# 1. Density based (with outlier detection)
# 2. Partitioning
# 3. Distribution based
# 4. Hierarchical
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. Advanced Unsupervised ML Algorithm
# 1. Principal Component Analysis
# 2. K Means
#
# #### PCA
#
# #### K Means
